# %%
# import cv2
# import os

# # Function to capture hand gesture images for training
# def capture_images(label, num_samples=300):
#     capture = cv2.VideoCapture(0)  # Open webcam
#     if not os.path.exists(f'dataset/{label}'):
#         os.makedirs(f'dataset/{label}')
        
#     print(f"Collecting {num_samples} samples for '{label}'")
    
#     count = 0
#     while True:
#         ret, frame = capture.read()
#         if not ret:
#             break
        
#         # Define the region of interest (ROI) for hand capture
#         roi = frame[100:400, 100:400]  # Adjust this region as per your hand placement
        
#         # Display the ROI
#         cv2.imshow('ROI', roi)
        
#         # Save the image in the specified directory
#         image_path = f'dataset/{label}/{count}.jpg'
#         cv2.imwrite(image_path, roi)
#         count += 1
        
#         # Display the webcam feed with ROI marked
#         cv2.rectangle(frame, (100, 100), (400, 400), (0, 255, 0), 2)
#         cv2.putText(frame, f'Samples Captured: {count}/{num_samples}', 
#                     (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
#         cv2.imshow('Webcam', frame)
        
#         # Break when the number of samples is reached or 'q' is pressed
#         if count >= num_samples or cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    
#     capture.release()
#     cv2.destroyAllWindows()

# # Example of collecting images for 'A' hand gesture
# capture_images('good')  # Collect images for sign 'A'

# %%
# import cv2
# import os

# # Function to capture hand gesture images on pressing 's' for each capture
# def capture_images(label, num_samples=300):
#     capture = cv2.VideoCapture(0)  # Open webcam
#     if not os.path.exists(f'dataset/{label}'):
#         os.makedirs(f'dataset/{label}')
        
#     print(f"Press 's' to capture an image for '{label}' (Total samples needed: {num_samples})")
    
#     count = 0
#     while True:
#         ret, frame = capture.read()
#         if not ret:
#             break
        
#         # Define the region of interest (ROI) for hand capture
#         roi = frame[100:400, 100:400]  # Adjust this region as per your hand placement
        
#         # Display the ROI
#         cv2.imshow('ROI', roi)
        
#         # Display the webcam feed with ROI marked
#         cv2.rectangle(frame, (100, 100), (400, 400), (0, 255, 0), 2)
#         cv2.putText(frame, f'Samples Captured: {count}/{num_samples}', 
#                     (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
#         cv2.imshow('Webcam', frame)
        
#         # Capture the image on pressing 's'
#         if cv2.waitKey(1) & 0xFF == ord('s'):
#             image_path = f'dataset/{label}/{count}.jpg'
#             cv2.imwrite(image_path, roi)
#             print(f"Captured image {count + 1}/{num_samples}")
#             count += 1
            
#         # Break when the number of samples is reached or 'q' is pressed
#         if count >= num_samples or cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    
#     capture.release()
#     cv2.destroyAllWindows()

# # Example of collecting images for 'good' hand gesture, capturing 1 pic per 's' press
# capture_images('fist', num_samples= 50)

# %%
# 2. Model Training (CNN)
# Now, use a Convolutional Neural Network (CNN) to train the model based on the collected dataset
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# num_classes = 8
# # Define CNN model
# def create_model():
#     model = Sequential()
    
#     # Convolutional layers
#     model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
#     model.add(MaxPooling2D(pool_size=(2, 2)))
    
#     model.add(Conv2D(64, (3, 3), activation='relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))
    
#     model.add(Conv2D(128, (3, 3), activation='relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))
    
#     # Flattening
#     model.add(Flatten())
    
#     # Fully connected layers
#     model.add(Dense(128, activation='relu'))
#     model.add(Dense(64, activation='relu'))
    
#     # Output layer (as many neurons as number of classes)
#     model.add(Dense(num_classes, activation='softmax'))  # Adjust 'num_classes' to match your dataset
    
#     return model

# %%
# n_classes = 8
# model = keras.models.Sequential([
    
#     # First convolutional layer
#     keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),
#     keras.layers.MaxPooling2D(2, 2),
# 
#     # Second convolutional layer
#     keras.layers.Conv2D(64, (3, 3), activation='relu'),
#     keras.layers.MaxPooling2D((2, 2)),

#     # Third convolutional layer
#     keras.layers.Conv2D(128, (3, 3), activation='relu'),
#     keras.layers.MaxPooling2D(2, 2),

#     # Flatten the output
#     keras.layers.Flatten(),
#     keras.layers.Dense(128, activation='relu'),
#     keras.layers.Dropout(0.5),  # Dropout for regularization
#     keras.layers.Dense(n_classes, activation='softmax')
# ])

# %%
# Initialize model and compile
# model = create_model()
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# lr_schedule = keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=0.001,
#     decay_steps=10000,
#     decay_rate=0.9)
# model.compile(optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])

# %%
# Image data generator for real-time augmentation
# train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
# training_set = train_datagen.flow_from_directory('dataset', target_size=(64, 64), batch_size=32, class_mode='categorical')

# %%
# model.summary()

# %%
# Train the model
# model.fit(training_set, epochs=10)
# history = model.fit(
#      train_ds,
#      epochs = EPOCHS,
#      batch_size=BATCH_SIZE,
#      verbose = 1,
#      validation_data = val_ds

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Number of classes
n_classes = 9

# Define the model architecture
model = keras.models.Sequential([
    # First convolutional layer
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),
    keras.layers.MaxPooling2D(2, 2),

    # Second convolutional layer
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),

    # Third convolutional layer
    keras.layers.Conv2D(128, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D(2, 2),

    # Flatten the output
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),  # Dropout for regularization
    keras.layers.Dense(n_classes, activation='softmax')
])

# Learning rate schedule
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=10000,
    decay_rate=0.9
)

# Compile the model
model.compile(optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Data augmentation and preparation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # Use 20% of the data for validation
)

# Create training and validation sets
training_set = train_datagen.flow_from_directory(
    'dataset3',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    subset='training'  # Set as training data
)

validation_set = train_datagen.flow_from_directory(
    'dataset3',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    subset='validation'  # Set as validation data
)

# Fit the model
model.fit(training_set, validation_data=validation_set, epochs=25)
# Out:
# Found 624 images belonging to 9 classes.
# Found 151 images belonging to 9 classes.
# Epoch 1/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.1853 - loss: 2.1723 - val_accuracy: 0.4834 - val_loss: 2.0140
# Epoch 2/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.2405 - loss: 2.0068 - val_accuracy: 0.5497 - val_loss: 1.6048
# Epoch 3/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.3814 - loss: 1.7061 - val_accuracy: 0.5695 - val_loss: 1.4492
# Epoch 4/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.4893 - loss: 1.4635 - val_accuracy: 0.5563 - val_loss: 1.2727
# Epoch 5/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.6100 - loss: 1.1429 - val_accuracy: 0.6556 - val_loss: 1.1680
# Epoch 6/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.6248 - loss: 1.0876 - val_accuracy: 0.5960 - val_loss: 1.0893
# Epoch 7/25
# ...

# %%
test_loss, test_acc = model.evaluate(training_set)
print(f'Validation Accuracy: {test_acc}')
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.9054 - loss: 0.2146
# Validation Accuracy: 0.9102563858032227

# %%
# Save the trained model
model.save('hand_model5.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# import cv2
# import os
# import numpy as np
# from tensorflow.keras.models import load_model

# %%
# Load the trained model
# model = load_model('hand_model3.h5')

# %%
# Real-time gesture detection
# def real_time_detection():
#     capture = cv2.VideoCapture(0)
    
#     while True:
#         ret, frame = capture.read()
#         if not ret:
#             break
        
#         # Extract the ROI from the frame
#         roi = frame[100:400, 100:400]
#         roi_resized = cv2.resize(roi, (64, 64))
#         roi_normalized = roi_resized / 255.0
        
#         # Make prediction
#         roi_input = np.expand_dims(roi_normalized, axis=0)
#         prediction = model.predict(roi_input)
#         predicted_class = np.argmax(prediction)
        
#         # Display prediction on frame
#         cv2.putText(frame, f'Predicted Gesture: {predicted_class}', 
#                     (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
#         cv2.rectangle(frame, (100, 100), (400, 400), (0, 255, 0), 2)
#         cv2.imshow('Webcam', frame)
        
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    
#     capture.release()
#     cv2.destroyAllWindows()

# # Run real-time detection
# real_time_detection()

# %%
# import cv2
# import numpy as np
# from tensorflow.keras.models import load_model

# # Load the pre-trained model (ensure the correct model path is specified)
# model = load_model('hand_model.h5')

# # Define class labels (adjust these to match the model's output classes)
# class_labels = ['fist', 'Hello', 'i lov u', 'okay', 'peace', 'call me', 'super', 'where']  # Example gestures

# # Real-time gesture detection
# def real_time_detection():
#     capture = cv2.VideoCapture(0)
    
#     while True:
#         ret, frame = capture.read()
#         if not ret:
#             break
        
#         # Extract the ROI from the frame (the hand area)
#         roi = frame[100:400, 100:400]
        
#         # Preprocess ROI for the model
#         roi_resized = cv2.resize(roi, (64, 64))  # Resize as per model input shape
#         roi_normalized = roi_resized / 255.0  # Normalize pixel values (0-1)
        
#         # Expand dimensions to match model input
#         roi_input = np.expand_dims(roi_normalized, axis=0)  # Shape (1, 64, 64, 3)
        
#         # Make prediction
#         prediction = model.predict(roi_input)
#         predicted_class = np.argmax(prediction)
        
#         # Map the predicted class to the actual gesture label
#         gesture = class_labels[predicted_class]
        
#         # Display prediction on the frame
#         cv2.putText(frame, f'Predicted Gesture: {gesture}', 
#                     (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
#         cv2.rectangle(frame, (100, 100), (400, 400), (0, 255, 0), 2)
#         cv2.imshow('Webcam', frame)
        
#         # Exit the loop on 'q' key press
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    
#     capture.release()
#     cv2.destroyAllWindows()

# # Run real-time detection
# real_time_detection()

# %%
# # Load the pre-trained model (ensure the correct model path is specified)
# model = load_model('hand_model3.h5')

# %%
# # Define class labels (adjust these to match the model's output classes)
# class_labels = ['fist', 'Hello', 'i love u', 'okay', 'peace', 'call me', 'super', 'where']

# # Initialize MediaPipe Hands
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7, min_tracking_confidence=0.5)
# mp_drawing = mp.solutions.drawing_utils

# # Real-time gesture detection
# def real_time_detection():
#     capture = cv2.VideoCapture(0)
    
#     while True:
#         ret, frame = capture.read()
#         if not ret:
#             break
        
#         # Flip the frame horizontally for a mirror-like effect
#         frame = cv2.flip(frame, 1)
        
#         # Convert the frame color to RGB (required for MediaPipe)
#         rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
#         # Process the frame with MediaPipe Hands
#         result = hands.process(rgb_frame)
        
#         if result.multi_hand_landmarks:
#             for hand_landmarks in result.multi_hand_landmarks:
#                 # Get the bounding box coordinates of the detected hand
#                 h, w, _ = frame.shape
#                 x_min = int(min([lm.x for lm in hand_landmarks.landmark]) * w)
#                 y_min = int(min([lm.y for lm in hand_landmarks.landmark]) * h)
#                 x_max = int(max([lm.x for lm in hand_landmarks.landmark]) * w)
#                 y_max = int(max([lm.y for lm in hand_landmarks.landmark]) * h)

#                 # Extract the ROI (Region of Interest) where the hand is located
#                 roi = frame[y_min:y_max, x_min:x_max]
                
#                 # Ensure the ROI has valid dimensions
#                 if roi.shape[0] > 0 and roi.shape[1] > 0:
#                     # Preprocess the ROI for the model
#                     roi_resized = cv2.resize(roi, (64, 64))  # Resize as per model input shape
#                     roi_normalized = roi_resized / 255.0  # Normalize pixel values (0-1)

#                     # Expand dimensions to match model input
#                     roi_input = np.expand_dims(roi_normalized, axis=0)  # Shape (1, 64, 64, 3)

#                     # Make prediction
#                     prediction = model.predict(roi_input)
#                     predicted_class = np.argmax(prediction)

#                     # Map the predicted class to the actual gesture label
#                     gesture = class_labels[predicted_class]

#                     # Display prediction on the frame
#                     cv2.putText(frame, f'Predicted Gesture: {gesture}', 
#                                 (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

#                 # Draw landmarks and bounding box
#                 mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS,
#                                           mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2),
#                                           mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2))
#                 cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
        
#         # Display the frame
#         cv2.imshow('Webcam', frame)
        
#         # Exit the loop on 'q' key press
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    
#     capture.release()
#     cv2.destroyAllWindows()

# # Run real-time detection
# real_time_detection()

# %%
# import cv2
# import numpy as np
# import mediapipe as mp
# from tensorflow.keras.models import load_model

# # Load your pre-trained model
# model = load_model('hand_model3.h5')

# # Define class labels
# class_labels = ['call me', 'fist', 'good', 'Hello', 'i lov u ', 'peace', 'super', 'where']

# # Initialize MediaPipe Hands
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7, min_tracking_confidence=0.5)
# mp_drawing = mp.solutions.drawing_utils

# def real_time_detection():
#     capture = cv2.VideoCapture(0)
    
#     while True:
#         ret, frame = capture.read()
#         if not ret:
#             break
        
#         # Flip the frame horizontally for a mirror-like effect
#         frame = cv2.flip(frame, 1)
        
#         # Convert the frame color to RGB (required for MediaPipe)
#         rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
#         # Process the frame with MediaPipe Hands
#         result = hands.process(rgb_frame)
        
#         if result.multi_hand_landmarks:
#             for hand_landmarks in result.multi_hand_landmarks:
#                 # Get the bounding box coordinates of the detected hand
#                 h, w, _ = frame.shape
#                 x_min = int(min([lm.x for lm in hand_landmarks.landmark]) * w)
#                 y_min = int(min([lm.y for lm in hand_landmarks.landmark]) * h)
#                 x_max = int(max([lm.x for lm in hand_landmarks.landmark]) * w)
#                 y_max = int(max([lm.y for lm in hand_landmarks.landmark]) * h)

#                 # Extract the ROI (Region of Interest) where the hand is located
#                 roi = frame[y_min:y_max, x_min:x_max]
                
#                 # Ensure the ROI has valid dimensions
#                 if roi.shape[0] > 0 and roi.shape[1] > 0:
#                     # Preprocess the ROI for the model
#                     roi_resized = cv2.resize(roi, (64, 64))  # Resize as per model input shape
#                     roi_normalized = roi_resized / 255.0  # Normalize pixel values (0-1)

#                     # Expand dimensions to match model input
#                     roi_input = np.expand_dims(roi_normalized, axis=0)  # Shape (1, 64, 64, 3)

#                     # Make prediction
#                     prediction = model.predict(roi_input)
#                     predicted_class = np.argmax(prediction)

#                     # Map the predicted class to the actual gesture label
#                     gesture = class_labels[predicted_class]

#                     # Display prediction on the frame
#                     cv2.putText(frame, f'Predicted Gesture: {gesture}', 
#                                 (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

#                 # Draw landmarks and bounding box
#                 mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS,
#                                           mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2),
#                                           mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2))
#                 cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
        
#         # Display the frame
#         cv2.imshow('Webcam', frame)
        
#         # Exit the loop on 'q' key press
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
    
#     capture.release()
#     cv2.destroyAllWindows()

# # Run real-time detection
# real_time_detection()

# %%
import cv2
import numpy as np
import mediapipe as mp
from tensorflow.keras.models import load_model

# Load your pre-trained model
model = load_model('hand_model4.h5')

# Define class labels
class_labels = ['C','del','nothing','S','space','V','Y','Z']

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7, min_tracking_confidence=0.5)
mp_drawing = mp.solutions.drawing_utils

def real_time_detection():
    capture = cv2.VideoCapture(0)
    
    while True:
        ret, frame = capture.read()
        if not ret:
            break
        
        # Flip the frame horizontally for a mirror-like effect
        frame = cv2.flip(frame, 1)
        
        # Convert the frame color to RGB (required for MediaPipe)
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Process the frame with MediaPipe Hands
        result = hands.process(rgb_frame)
        
        if result.multi_hand_landmarks:
            for hand_landmarks in result.multi_hand_landmarks:
                # Get the bounding box coordinates of the detected hand
                h, w, _ = frame.shape
                x_min = int(min([lm.x for lm in hand_landmarks.landmark]) * w)
                y_min = int(min([lm.y for lm in hand_landmarks.landmark]) * h)
                x_max = int(max([lm.x for lm in hand_landmarks.landmark]) * w)
                y_max = int(max([lm.y for lm in hand_landmarks.landmark]) * h)

                # Ensure the ROI has valid dimensions
                if (y_max - y_min) > 0 and (x_max - x_min) > 0:
                    # Extract the ROI
                    roi = frame[y_min:y_max, x_min:x_max]

                    # Resize and normalize ROI for the model
                    roi_resized = cv2.resize(roi, (64, 64 ))  # Resize as per model input shape
                    roi_normalized = roi_resized / 255.0  # Normalize pixel values (0-1)

                    # Expand dimensions to match model input
                    roi_input = np.expand_dims(roi_normalized, axis=0)  # Shape (1, 64, 64, 3)

                    try:
                        # Make prediction
                        prediction = model.predict(roi_input)
                        predicted_class = np.argmax(prediction)

                        # Map the predicted class to the actual gesture label
                        gesture = class_labels[predicted_class]

                        # Display prediction on the frame
                        cv2.putText(frame, f'Predicted Gesture: {gesture}', 
                                    (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

                    except Exception as e:
                        print(f"Prediction error: {e}")

                # Draw landmarks and bounding box
                mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS,
                                          mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2),
                                          mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2))
                cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
        
        # Display the frame
        cv2.imshow('Webcam', frame)
        
        # Exit the loop on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    capture.release()
    cv2.destroyAllWindows()

# Run real-time detection
real_time_detection()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ...
